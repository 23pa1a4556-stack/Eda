# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/housing_prices_regression.csv")
df.isnull().sum()
# Out:
# num_bedrooms     22
# year_built       19
# zipcode_dup      30
# zipcode          30
# size_sqft        23
# has_garage       23
# id               30
# has_garden       28
# num_bathrooms    39
# sale_price       22
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   num_bedrooms   238 non-null    float64
#  1   year_built     241 non-null    float64
#  2   zipcode_dup    230 non-null    float64
#  3   zipcode        230 non-null    float64
#  4   size_sqft      237 non-null    object
#  5   has_garage     237 non-null    object
#  6   id             230 non-null    object
#  7   has_garden     232 non-null    object
#  8   num_bathrooms  221 non-null    float64
#  9   sale_price     238 non-null    float64
# dtypes: float64(6), object(4)
# memory usage: 20.4+ KB

# %%
df
# Out:
#      num_bedrooms  year_built  zipcode_dup   zipcode size_sqft has_garage  \
# 0             2.0      2021.0     110002.0  110002.0      1075         Ys
# 1             3.0      1954.0     560001.0  560001.0      1482         Ye
# 2             2.0      1991.0     560002.0  560002.0      1689         No
# 3             3.0      1956.0          NaN       NaN      1415        Yes
# 4             NaN      1991.0     560001.0  560001.0      1765         No
# ..            ...         ...          ...       ...       ...        ...
# 255           2.0      1950.0     110001.0  110001.0      1402         No
# 256           2.0      1991.0     560002.0  560002.0      1689         No
# 257           3.0      1954.0     560001.0  560001.0      1482         Ye
# 258           3.0      1974.0     110003.0  110003.0      1239        YES
# 259           2.0      1999.0     110002.0  110002.0      1399         NO
#
#          id has_garden  num_bathrooms  sale_price
# 0    H20000        NaN            3.0         NaN
# 1    H20001          o            1.5   293483.53
# 2    H20002         No            2.5   179736.91
# 3    H20003         es            NaN   462700.04
# 4    H20004         NO            1.0   272214.40
# ..      ...        ...            ...         ...
# 255  H20012         NO            2.0         NaN
# 256  H20002         No            2.5   179736.91
# 257  H20001          o            1.5   293483.53
# 258     NaN        NaN            2.0   701046.18
# 259  H20093         No            2.5    48165.82
#
# [260 rows x 10 columns]

# %%
df['num_bedrooms']=df['num_bedrooms'].fillna(df['num_bedrooms'].mean())
df['num_bedrooms']=df['num_bedrooms'].astype(int)
df['num_bedrooms']
# Out:
# 0      2
# 1      3
# 2      2
# 3      3
# 4      2
#       ..
# 255    2
# 256    2
# 257    3
# 258    3
# 259    2
# Name: num_bedrooms, Length: 260, dtype: int64

# %%
df['year_built']=df['year_built'].fillna(df['year_built'].mean())
df['year_built']=df['year_built'].astype(int)
df['year_built']
# Out:
# 0      2021
# 1      1954
# 2      1991
# 3      1956
# 4      1991
#        ...
# 255    1950
# 256    1991
# 257    1954
# 258    1974
# 259    1999
# Name: year_built, Length: 260, dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (250, 10)

# %%
df['zipcode']=df['zipcode'].fillna(df['zipcode'].mode()[0])
df['zipcode']=df['zipcode'].astype(int)
df['zipcode']
# Out:
# 0      110002
# 1      560001
# 2      560002
# 3      110001
# 4      560001
#         ...
# 245    110002
# 246    110001
# 247    110001
# 248    560002
# 249    110001
# Name: zipcode, Length: 250, dtype: int64

# %%
df['zipcode_dup']=df['zipcode_dup'].fillna(df['zipcode_dup'].mode()[0])
df['zipcode_dup']=df['zipcode_dup'].astype(int)
df['zipcode_dup']
# Out:
# 0      110002
# 1      560001
# 2      560002
# 3      110001
# 4      560001
#         ...
# 245    110002
# 246    110001
# 247    110001
# 248    560002
# 249    110001
# Name: zipcode_dup, Length: 250, dtype: int64

# %%
df['num_bathrooms']=df['num_bathrooms'].fillna(df['num_bathrooms'].mode()[0])
df['num_bathrooms']=df['num_bathrooms'].astype(int)
df['num_bathrooms']
# Out:
# 0      3
# 1      1
# 2      2
# 3      3
# 4      1
#       ..
# 245    2
# 246    1
# 247    3
# 248    3
# 249    2
# Name: num_bathrooms, Length: 250, dtype: int64

# %%
df['sale_price']=df['sale_price'].fillna(df['sale_price'].mean())
df['sale_price']=df['sale_price'].astype(int)
df
# Out:
#      num_bedrooms  year_built  zipcode_dup  zipcode size_sqft has_garage  \
# 0               2        2021       110002   110002      1075         Ys
# 1               3        1954       560001   560001      1482         Ye
# 2               2        1991       560002   560002      1689         No
# 3               3        1956       110001   110001      1415        Yes
# 4               2        1991       560001   560001      1765         No
# ..            ...         ...          ...      ...       ...        ...
# 245             2        1990       110002   110002      1013          N
# 246             5        1982       110001   110001      1907         No
# 247             2        1965       110001   110001       NaN        YES
# 248             2        1972       560002   560002      1760         No
# 249             3        1956       110001   110001      1824          N
#
#          id has_garden  num_bathrooms  sale_price
# 0    H20000        NaN              3      427304
# 1    H20001          o              1      293483
# 2    H20002         No              2      179736
# 3    H20003         es              3      462700
# 4    H20004         NO              1      272214
# ..      ...        ...            ...         ...
# 245  H20245         Ye              2      248078
# 246  H20246          o              1      708685
# 247  H20247         No              3      487109
# 248  H20248          o              3      498054
# 249  H20249          N              2      340590
#
# [250 rows x 10 columns]

# %%
df['size_sqft']=pd.to_numeric(df['size_sqft'],errors='coerce')
df['size_sqft']=df['size_sqft'].fillna(df['size_sqft'].median())
df['size_sqft']
# Out:
# 0      1075.0
# 1      1482.0
# 2      1689.0
# 3      1415.0
# 4      1765.0
#         ...
# 245    1013.0
# 246    1907.0
# 247    1513.0
# 248    1760.0
# 249    1824.0
# Name: size_sqft, Length: 250, dtype: float64

# %%
df['has_garage'].unique()
df["has_garden"].replace({'Yes': 'Yes', 'Ye': 'Yes', 'Ys': 'Yes', 'YES': 'Yes', 'es': 'Yes','No': 'No', 'N': 'No', 'NO': 'No', 'o': 'No' },inplace=True)
df["has_garden"].fillna(df["has_garden"].mode()[0], inplace=True)
df
# Out:
# /tmp/ipython-input-1552934971.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["has_garden"].replace({'Yes': 'Yes', 'Ye': 'Yes', 'Ys': 'Yes', 'YES': 'Yes', 'es': 'Yes','No': 'No', 'N': 'No', 'NO': 'No', 'o': 'No' },inplace=True)
#      num_bedrooms  year_built  zipcode_dup  zipcode  size_sqft has_garage  \
# 0               2        2021       110002   110002     1075.0         Ys
# 1               3        1954       560001   560001     1482.0         Ye
# 2               2        1991       560002   560002     1689.0         No
# 3               3        1956       110001   110001     1415.0        Yes
# 4               2        1991       560001   560001     1765.0         No
# ..            ...         ...          ...      ...        ...        ...
# 245             2        1990       110002   110002     1013.0          N
# 246             5        1982       110001   110001     1907.0         No
# 247             2        1965       110001   110001     1513.0        YES
# 248             2        1972       560002   560002     1760.0         No
# 249             3        1956       110001   110001     1824.0          N
#
#          id has_garden  num_bathrooms  sale_price
# 0    H20000         No              3      427304
# 1    H20001         No              1      293483
# 2    H20002         No              2      179736
# 3    H20003        Yes              3      462700
# 4    H20004         No              1      272214
# ..      ...        ...            ...         ...
# 245  H20245        Yes              2      248078
# 246  H20246         No              1      708685
# 247  H20247         No              3      487109
# 248  H20248         No              3      498054
# 249  H20249         No              2      340590
#
# [250 rows x 10 columns]

# %%
df["has_garage"].replace({'Yes': 'Yes', 'Ye': 'Yes', 'Ys': 'Yes', 'YES': 'Yes', 'es': 'Yes','No': 'No', 'N': 'No', 'NO': 'No', 'o': 'No' },inplace=True)
df["has_garage"].fillna(df["has_garage"].mode()[0], inplace=True)
df
# Out:
# /tmp/ipython-input-4169048964.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["has_garage"].replace({'Yes': 'Yes', 'Ye': 'Yes', 'Ys': 'Yes', 'YES': 'Yes', 'es': 'Yes','No': 'No', 'N': 'No', 'NO': 'No', 'o': 'No' },inplace=True)
#      num_bedrooms  year_built  zipcode_dup  zipcode  size_sqft has_garage  \
# 0               2        2021       110002   110002     1075.0        Yes
# 1               3        1954       560001   560001     1482.0        Yes
# 2               2        1991       560002   560002     1689.0         No
# 3               3        1956       110001   110001     1415.0        Yes
# 4               2        1991       560001   560001     1765.0         No
# ..            ...         ...          ...      ...        ...        ...
# 245             2        1990       110002   110002     1013.0         No
# 246             5        1982       110001   110001     1907.0         No
# 247             2        1965       110001   110001     1513.0        Yes
# 248             2        1972       560002   560002     1760.0         No
# 249             3        1956       110001   110001     1824.0         No
#
#          id has_garden  num_bathrooms  sale_price
# 0    H20000         No              3      427304
# 1    H20001         No              1      293483
# 2    H20002         No              2      179736
# 3    H20003        Yes              3      462700
# 4    H20004         No              1      272214
# ..      ...        ...            ...         ...
# 245  H20245        Yes              2      248078
# 246  H20246         No              1      708685
# 247  H20247         No              3      487109
# 248  H20248         No              3      498054
# 249  H20249         No              2      340590
#
# [250 rows x 10 columns]

# %%
df["id"].unique()


# Drop rows where 'id' is NaN
df.dropna(subset=["id"], inplace=True)
df
# Out:
#      num_bedrooms  year_built  zipcode_dup  zipcode  size_sqft has_garage  \
# 0               2        2021       110002   110002     1075.0        Yes
# 1               3        1954       560001   560001     1482.0        Yes
# 2               2        1991       560002   560002     1689.0         No
# 3               3        1956       110001   110001     1415.0        Yes
# 4               2        1991       560001   560001     1765.0         No
# ..            ...         ...          ...      ...        ...        ...
# 245             2        1990       110002   110002     1013.0         No
# 246             5        1982       110001   110001     1907.0         No
# 247             2        1965       110001   110001     1513.0        Yes
# 248             2        1972       560002   560002     1760.0         No
# 249             3        1956       110001   110001     1824.0         No
#
#          id has_garden  num_bathrooms  sale_price
# 0    H20000         No              3      427304
# 1    H20001         No              1      293483
# 2    H20002         No              2      179736
# 3    H20003        Yes              3      462700
# 4    H20004         No              1      272214
# ..      ...        ...            ...         ...
# 245  H20245        Yes              2      248078
# 246  H20246         No              1      708685
# 247  H20247         No              3      487109
# 248  H20248         No              3      498054
# 249  H20249         No              2      340590
#
# [221 rows x 10 columns]

# %%
df.to_csv('cleaned_dataset1.csv')

# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Load dataset


# Step 3: Compute correlation matrix (only numeric columns)
corr = df.corr(numeric_only=True)

# Step 4: Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of Housing Dataset", fontsize=14)
plt.show()

# %%
plt.scatter(df["size_sqft"], df["sale_price"], color="teal", alpha=0.6)
plt.title("Sales Price vs Size (sqft)")
plt.xlabel("Size (sqft)")
plt.ylabel("Sales Price")
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
plt.boxplot([df[df["num_bathrooms"] == b]["sale_price"] for b in sorted(df["num_bathrooms"].dropna().unique())],
            labels=sorted(df["num_bathrooms"].dropna().unique()))
plt.title("Sales Price by Number of Bathrooms")
plt.xlabel("Number of Bathrooms")
plt.ylabel("Sales Price")
plt.show()
# Out:
# /tmp/ipython-input-2748068879.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df[df["num_bathrooms"] == b]["sale_price"] for b in sorted(df["num_bathrooms"].dropna().unique())],

# %%
plt.hist(df["sale_price"], bins=20, color='skyblue', edgecolor='black')
plt.title("Distribution of Sale Prices")
plt.xlabel("Sale Price")
plt.ylabel("Frequency")
plt.show()

# %%
df["has_garden"].value_counts().plot.pie(autopct="%1.1f%%", colors=["lightblue", "pink"])
plt.title("Percentage of Houses with/without Garden")
plt.ylabel("Count of Houses")
plt.xlabel("Garden Availability")
plt.show()

# %%
avg_price = df.groupby("num_bathrooms")["sale_price"].mean()

# Plot line chart
plt.plot(avg_price.index, avg_price.values, marker='o')
plt.title("Average Sale Price vs Number of Bathrooms")
plt.xlabel("Number of Bathrooms")
plt.ylabel("Average Sale Price")
plt.grid(True)
plt.show()

# %%
plt.bar(df["has_garage"].value_counts().index, df["has_garage"].value_counts().values, color="orange")
plt.title("Houses with and without Garage")
plt.xlabel("Garage Availability")
plt.ylabel("Count")
plt.show()

# %%
avg_price_by_year = df.groupby("year_built")["sale_price"].mean().sort_index()
plt.figure(figsize=(8,5))
plt.plot(avg_price_by_year.index, avg_price_by_year.values, marker='o', color='teal', linestyle='-', linewidth=2)
plt.title("Average Sale Price by Year Built", fontsize=14)
plt.xlabel("Year Built", fontsize=12)
plt.ylabel("Average Sale Price", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
df.boxplot(column="sale_price", by="zipcode", grid=False, patch_artist=True)
plt.title("Distribution of Sale Price by Zipcode", fontsize=14)
plt.xlabel("Zipcode", fontsize=12)
plt.ylabel("Sale Price", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Anaysis from our project**

# %% [markdown]
# The data analysis reveals several important insights about the housing market:
#
# 1. House size and the number of rooms are strong indicators of higher sale prices.
# 2. Location (zipcode) significantly influences property values — some areas are much more expensive.
# 3. Houses with garages or gardens tend to have higher prices compared to those without.
# 4. The distribution of sale prices is skewed, showing a mix of both affordable and luxury properties.
# 5. Year built also affects value slightly — newer houses generally command higher prices.
#
# Overall, these findings highlight how multiple features together influence house pricing trends.
